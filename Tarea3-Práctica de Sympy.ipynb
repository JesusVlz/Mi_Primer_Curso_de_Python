# %% [markdown]
# Primeramente llama a la paqueteria junto con todas sus funciones como se vio en clase

# %%
from sympy import *

# %% [markdown]
# <details><summary>Click aquí para ver la solución</summary>
#
# ```python
# from sympy import *
# ```
#
# </details>

# %% [markdown]
# Resolver para x lo siguiente
# $$x^3 - 3x^2 -4x +12= 0$$

# %% [markdown]
# <details><summary>Click aquí para ver la solución</summary>
#
# ```python
# #Es importante definir primero un simbolo para
# x=symbols("x")
# #Luego escribimos nuestra expresión
# exp=Eq(x**3-x**2+5*x-10,0)
# solve(exp)
# ```
#
# </details>

# %% [markdown]
# Tratemos de resolver el siguiente sistema de ecuaciones lineales, por ejemplo:
#
# $$y - x + 2z - 3 = 0$$
# $$x- 2y -z = 10$$
# $$2y - 3x + 5z -6 = 0$$
#
# Declarando variables con cada una de las expresiones como se vio en clase

# %% [markdown]
# <details><summary>Click aquí para ver una pista</summary>
#
# ```python
# #Recuerde definir los simbolos , por ejemplo
# x=symbols("x")
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click aquí para ver la solución</summary>
#
# ```python
# #Luego escribimos nuestra expresión
# exp1=Eq(y-x+2*z-3,0)
# exp2=Eq(y-2*x+2*z-3,10)
# exp3=Eq(3*y-x+2*z-30,0)
# solve([exp1, exp2,exp3], [x, y,z])
# ```
#
# </details>

# %% [markdown]
# Derive la siguiente expresion :
#
# $$f(x)=6x^3 + 2x^2 + 5x$$

# %% [markdown]
# Integre la siguiente expresion
#
# $$f(x)=\sqrt(x)$$

# %% [markdown]
# Realice el desarrollo en serie de la función
#
#
# $$f(x)=sen(x)$$

# %% [markdown]
# Llame al modulo plotting de sympy para graficar lo siguiente:
#
#
# $$(x-5)^3 -2 $$
# $$ 2x^2 + 3y^2 = 10$$

# %% [markdown]
# <details><summary>Click aquí ver una pista</summary>
#
# ```python
# from sympy.plotting import *
# x = symbols("x")
# y = symbols("y")
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click para ver la solución</summary>
#
# ```python
# #Recuerde que para graficar con dos variables debemos usar el siguiente comando:
#
# plot_implicit(Eq(2*x**2 + 3*y**2,10),(x,-7,7),(y,-7,7))
#
#
# ```
#
# </details>
