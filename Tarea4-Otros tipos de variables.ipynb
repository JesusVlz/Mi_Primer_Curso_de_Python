# %% [markdown]
#  Considere la siguiente tupla:

# %%
generos_tuple = ("pop", "rock", "soul", "hard rock", "soft rock","R&B", "progressive rock", "disco") 
generos_tuple

# %% [markdown]
# Encuentra la longitud de la tupla, <code>generos_tuple</code>:

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# len(genres_tuple)
# ```
#
# </details>

# %% [markdown]
# Acceda al elemento, con respecto al índice 3:

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# generos_tuple[3]
#
# ```
#
# </details>

# %% [markdown]
# Encuentra los dos primeros elementos de la tupla <code>generos_tuple</code>:

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# generos_tuple[0,2]
#
# ```
#
# </details>

# %% [markdown]
# Crea una lista <code>a_list</code>, con los siguientes elementos <code>1</code>, <code>hola</code>, <code>[1,2,3]</code> y <code>True</code>.

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# a_list = [1, 'hello', [1, 2, 3] , True]
# a_list
# ```
#
# </details>

# %% [markdown]
# Elimine el elemento Booleano de la anterior lista

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# a_list.remove("hello")
# a_list
# ```
#
# </details>

# %% [markdown]
# Concatene las siguientes listas <code>A = [1, 'a']</code> y <code>B = [2, 1, 'd']</code>:

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# A = [1, 'a']
# B = [2, 1, 'd']
# A + B
#
# ```
#
# </details>

# %% [markdown]
# Considere la lista <code>A = [1, 2, 2, 1]</code> y establezca <code>B = set([1, 2, 2, 1])</code>, ¿La suma de sus elementos son iguales ?

# %%
#sugerencia use sum (A) y sum(B)

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# A = [1, 2, 2, 1]
# B = set([1, 2, 2, 1])
# print("the sum of A is:", sum(A))
# print("the sum of B is:", sum(B))
#
# ```
#
# </details>

# %% [markdown]
# Convierta la lista <code>['rap','house','electronic music', 'rap']</code> en un conjunto:

# %% [markdown]
# <details><summary>Click aquí para ver la solucion</summary>
#
# ```python
# set(['rap','house','electronic music','rap'])
#
#
# ```
#
# </details>

# %% [markdown]
#  Considere el siguiente diccionario:

# %%
peliculas_dic = {"The Avengers":"2012", "Matrix":"1999"}

# %% [markdown]
# ¿Cuales son las claves de este diccionario?
# Sugerencia: Use .keys()

# %% [markdown]
# <details><summary>Clic para ver la solucion</summary>
#
# ```python
# peliculas_dic.keys()
#
# ```
#
# </details>

# %% [markdown]
# ¿Cuales son los valores de este diccionario?
# Sugerencia: Use .values()

# %% [markdown]
# Accede a la fecha de lanzamiento de la pelicula de The Avengers

# %% [markdown]
# <details><summary>Clic para ver la solucion</summary>
#
# ```python
# peliculas_dic["The Avengers"]
#
# ```
#
# </details>

# %% [markdown]
# Escribe un bucle <code>for</code> que imprime todos los elementos entre <b>-5</b> y <b>5</b> usando la función de rango.

# %% [markdown]
# <details><summary>Clic para ver la solucion</summary>
#
# ```python
# for i in range(-4, 5):
#     print(i)
#
# ```
#
# </details>

# %% [markdown]
# Encuentre el valor de <code> x </code> que imprimirá la secuencia <code> 1,2,..,10 </code>:

# %%
x=
y=1
while(y != x):
    print(y)
    y=y+1

# %% [markdown]
# Crea una función que divida la primera entrada por la segunda entrada  y pruebela :

# %% [markdown]
# <details><summary>Clic para ver la solucion</summary>
#
# ```python
# def div(a, b):
#     return(a/b)
# ```
#
# </details>
